# %% [markdown]
# # 変数、データ型、制御文

# %% [markdown]
# # 変数

# %%
#var i = ""

#Python：型推論
i = ""

#インデント注意　２個か４個
 i = ""
# Out:
#   File "<ipython-input-4-29063dbfd1cf>", line 3
#     i = ""
#     ^
# IndentationError: unexpected indent

# %%
#python2.7
# print ""
#python3.5
print("hello world!!")
# Out:
# hello world!!

# %%
i = ""
print(type(i))
i = 1
print(type(i))
i = 1.
print(type(i))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
#配列：リスト型
l = []
l = [1,2,3,4]
print(l)
print(type(l))

#辞書型
d2 = {}
d2["userid"] = "user1"
d2["user"] = "太郎"

post1 = {}
post1["postid"] = "温泉の入り方"
post1["detail"] = "本文"

d2["post"] = post1
print(d2)
print(type(d2))

import json
print(json.dumps(d2))
# Out:
# [1, 2, 3, 4]
# <class 'list'>
# {'userid': 'user1', 'user': '太郎', 'post': {'postid': '温泉の入り方', 'detail': '本文'}}
# <class 'dict'>
# {"userid": "user1", "user": "\u592a\u90ce", "post": {"postid": "\u6e29\u6cc9\u306e\u5165\u308a\u65b9", "detail": "\u672c\u6587"}}

# %%
#タプル型
t = (1,2)
print(type(t))
# Out:
# <class 'tuple'>

# %%
#インデックス、スライス

l = ["a", "b", "c"]
#インデックスでアクセス
print(l[1])
print(l[2])
l[2] = "d"
print(l)
# Out:
# b
# c
# ['a', 'b', 'd']

# %%
l[0:3]
# Out:
# ['a', 'b', 'd']

# %%
l[:]
# Out:
# ['a', 'b', 'd']

# %%
"abcde"[1]
# Out:
# 'b'

# %%
"abcde"[1:3]
# Out:
# 'bc'

# %%
d2 = {}
d2["userid"] = "user1"
d2["user"] = "太郎"

print(d2["userid"])
# Out:
# user1

# %% [markdown]
# # せいぎょぶん

# %%
#ここ勝手に変換してる。
i = "a"
print(type(i))
if 100 == i:
  print("hit")
# else:
#   print("not hit")
# Out:
# <class 'str'>

# %%
# for(i=1;i>10;i++)
# {
# }

for i in range(2):
  print("!", i)

l = [1,2,3,4,5]

for i in l:
  print(i)
# Out:
# ! 0
# ! 1
# 1
# 2
# 3
# 4
# 5

# %%
#zipは２個のリストを一気に回す
for (i1, i2, i3) in zip(l, l, l):
  print(i1)
  print(i2)
  print(i3)
  if i1 == 1:
      break
  
#   continue
# Out:
# 1
# 1
# 1

# %%
i = 1
while i < 5:
  i += 1
  print(i)
# Out:
# 2
# 3
# 4
# 5

# %% [markdown]
# # コメント

# %%
# !!!!

"""
コメント！
"""


'''
コメント
'''
# Out:
# '\nコメント\n'

# %% [markdown]
# # 関数

# %%
def sum1(x1, x2):
   return x1+x2

print(sum1(1,2))

print(sum1(1,3))
# Out:
# 3
# 4

# %% [markdown]
# # クラス

# %%
class myClass():
    #コンストラクタ：インスタンス生成時に呼ばれる
    def __init__(self):
        print("init")
    def sum1(self , x1, x2):
        return x1+x2

c = myClass()
print(c.sum1(1,2))
# Out:
# init
# 3
